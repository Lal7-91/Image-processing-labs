# %%
# Task 2:

# a:

import cv2
img = cv2.imread('Images/cat.jpg') #Load the
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
# task 2 b:
from PIL import Image
img2 = Image.open('Images/swain.gif') #load
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(img2, cmap = cm.Greys_r)
plt.show()

# %%
# task 3 a:
cv2.imwrite('new_image.jpg', img)
# Out:
# True

# %%
# task 3 b:
img2.save('new_image2.jpg')

# %%
# task 4:
print(img.shape) #Note: img1 loaded using open cv is a numpy array
print(img)
# Out:
# (400, 600, 3)
# [[[  6   6   6]
#   [  4   4   4]
#   [  6   6   6]
#   ...
#   [ 54  54  54]
#   [ 79  79  79]
#   [102 102 102]]
#
#  [[  6   6   6]
#   [  6   6   6]
#   [  5   5   5]
#   ...
#   [ 51  51  51]
#   [ 78  78  78]
#   [102 102 102]]
#
#  [[  5   5   5]
#   [  8   8   8]
#   [  7   7   7]
#   ...
#   [ 51  51  51]
#   [ 82  82  82]
#   [103 103 103]]
#
#  ...
#
#  [[ 36  36  36]
#   [ 35  35  35]
#   [ 34  34  34]
#   ...
#   [ 73  73  73]
#   [ 76  76  76]
#   [ 75  75  75]]
#
#  [[ 34  34  34]
#   [ 35  35  35]
#   [ 35  35  35]
#   ...
#   [ 73  73  73]
#   [ 76  76  76]
#   [ 77  77  77]]
#
#  [[ 38  38  38]
#   [ 37  37  37]
#   [ 35  35  35]
#   ...
#   [ 74  74  74]
#   [ 76  76  76]
#   [ 75  75  75]]]

# %%
import numpy as np
# Convert the image to a NumPy array
img_array = np.array(img2)
# Print the array
print(img_array.shape)
print(img_array)
# Out:
# (512, 512)
# [[ 78  79  79 ...  86  86  86]
#  [ 78  79  79 ...  86  86  86]
#  [ 79  78  78 ...  94  86  86]
#  ...
#  [ 98 109 102 ... 137 152 135]
#  [118 122 122 ... 121 131 133]
#  [129 131 129 ... 102 127 131]]
